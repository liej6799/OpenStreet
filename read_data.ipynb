# %%
#Read Data

# %%
# Library
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
#General Settings
folder = 'video-data/kitti/2011_09_26_drive_0001_extract/image_02/data/'
image = '0000000113.png'

# %%
def get
img = cv2.imread(folder + image) # reads image 'opencv-logo.png' as grayscale
plt.imshow(img)
